# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/train-features-2/Boruta_data_shock/boruta_test_summ.csv
# /kaggle/input/train-features-2/Boruta_data_shock/boruta_val_summ.csv
# /kaggle/input/train-features-2/Boruta_data_shock/boruta_train_summ.csv
# /kaggle/input/train-features-1/boruta_data_los/boruta_test_summ.csv
# /kaggle/input/train-features-1/boruta_data_los/boruta_val_summ.csv
# /kaggle/input/train-features-1/boruta_data_los/boruta_train_summ.csv
# /kaggle/input/uploaded-data/Processed_Dataset.csv
# /kaggle/input/train-features/boruta_data/boruta_test_summ.csv
# /kaggle/input/train-features/boruta_data/boruta_val_summ.csv
# /kaggle/input/train-features/boruta_data/boruta_train_summ.csv

# %%
# for making a shell able to execute python
# from IPython.core.interactiveshell import InteractiveShell
# InteractiveShell.ast_node_iteractivity = "all"

import pandas as pd
import numpy as np

# %%
# Loading boruta selected features for training the classification model

train_df = pd.read_csv("/kaggle/input/train-features/boruta_data/boruta_train_summ.csv")
val_df = pd.read_csv("/kaggle/input/train-features/boruta_data/boruta_val_summ.csv")
test_df = pd.read_csv("/kaggle/input/train-features/boruta_data/boruta_test_summ.csv")

# %%
# Sklearn provides selection of tools for machine learning and stats modelling
# For classification, regression, clusering, dimensionality reduction

import sklearn
sklearn.__version__
# Out:
# '0.24.1'

# %%
train_df.head()
# Out:
#                           id  label  X.HR.__approximate_entropy__m_2__r_0.5  \
# 0   p000052_261857_1_54_1591      1                                0.618257
# 1    p000138_275067_1_22_631      0                               -0.148506
# 2    p000138_275067_1_22_631      0                               -0.148506
# 3   p000222_260665_1_48_1411      1                                1.096153
# 4  p000357_235292_1_289_8641      0                               -0.762110
#
#    X.HR.__approximate_entropy__m_2__r_0.9  \
# 0                                1.044650
# 1                               -0.342751
# 2                               -0.342751
# 3                               -0.096509
# 4                               -0.609662
#
#    X.HR.__change_quantiles__f_agg_.var.__isabs_True__qh_0.8__ql_0.6  \
# 0                                          -0.737736
# 1                                           0.080624
# 2                                           0.080624
# 3                                          -0.507551
# 4                                          -0.524244
#
#    X.HR.__cwt_coefficients__widths_.2..5..10..20.__coeff_0__w_2  \
# 0                                          -0.097681
# 1                                          -6.734420
# 2                                          -6.734420
# 3                                          -0.236171
# 4                                          -0.008936
#
#    X.HR.__energy_ratio_by_chunks__num_segments_10__segment_focus_3  \
# 0                                           0.364471
# 1                                           0.018978
# 2                                           0.018978
# 3                                          -0.016998
# 4                                           1.306357
#
#    X.HR.__energy_ratio_by_chunks__num_segments_10__segment_focus_4  \
# 0                                          -0.454931
# 1                                          -0.514977
# 2                                          -0.514977
# 3                                           0.616561
# 4                                          -0.282198
#
#    X.HR.__energy_ratio_by_chunks__num_segments_10__segment_focus_7  \
# 0                                           0.252518
# 1                                           1.503207
# 2                                           1.503207
# 3                                          -0.496964
# 4                                          -0.056869
#
#    X.HR.__fft_coefficient__coeff_10__attr_.abs.  ...  \
# 0                                     -0.705528  ...
# 1                                      1.118543  ...
# 2                                      1.118543  ...
# 3                                     -0.878014  ...
# 4                                     -0.752127  ...
#
#    final_abp_sys__standard_deviation  \
# 0                          -1.032898
# 1                           0.800748
# 2                           0.800748
# 3                          -1.134580
# 4                          -0.838502
#
#    final_abp_sys__sum_of_reoccurring_data_points  \
# 0                                      -0.308462
# 1                                      -0.892388
# 2                                      -0.892388
# 3                                       0.931446
# 4                                       0.545574
#
#    final_abp_sys__sum_of_reoccurring_values  final_abp_sys__sum_values  \
# 0                                 -0.875743                   0.030331
# 1                                  1.855497                   0.079512
# 2                                  1.855497                   0.079512
# 3                                 -0.805948                   1.022362
# 4                                 -0.825995                  -0.353084
#
#    final_abp_sys__time_reversal_asymmetry_statistic__lag_1  \
# 0                                          -0.167471
# 1                                           0.699096
# 2                                           0.699096
# 3                                          -0.080426
# 4                                          -0.505237
#
#    final_abp_sys__time_reversal_asymmetry_statistic__lag_2  \
# 0                                          -0.226271
# 1                                           0.959605
# 2                                           0.959605
# 3                                          -0.109288
# 4                                          -0.651549
#
#    final_abp_sys__time_reversal_asymmetry_statistic__lag_3  \
# 0                                          -0.222942
# 1                                           0.971670
# 2                                           0.971670
# 3                                          -0.102547
# 4                                          -0.633149
#
#    final_abp_sys__variance  GENDER       age
# 0                -0.509582       M -0.697431
# 1                 0.342319       M -0.503556
# 2                 0.342319       M -0.503556
# 3                -0.522869       F -0.094353
# 4                -0.474249       M -0.175657
#
# [5 rows x 446 columns]

# %%
print("Shape of training set: ", train_df.shape)
print("Shape of validation set: ", val_df.shape)
print("Shape of test set: ", test_df.shape)
# Out:
# Shape of training set:  (1332, 446)
# Shape of validation set:  (392, 446)
# Shape of test set:  (392, 446)

# %% [markdown]
# This indicates 1332 patients in train set, 392 patients in validation set and 392 patients in test set. Each segment having 1 patient ID, label variable and 444 features

# %%
# Extracting only the features
X = train_df[train_df.columns.difference(['id', 'label', 'age', 'GENDER'])]

# Extracting the target variable
Y = train_df[['label']]

X_train = X
y_train = np.array(Y)

# %% [markdown]
# ## Basic Random Forest model for AHE prediction

# %%
from sklearn.ensemble import RandomForestClassifier

model_ahe = RandomForestClassifier(n_estimators=1750)
# n_estimators is the number of trees
# default value of n_estimators is 10

# %%
model_ahe.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(n_estimators=1750)

# %%
# preparing the test set in the same way
X_test = test_df[test_df.columns.difference(['id', 'label', 'age', 'GENDER'])]
y_test = np.array(test_df[['label']])

# %%
y_probability = model_ahe.predict_proba(X_test)
y_predicted = (y_probability[:,1]>=0.59).astype('int') 
# taking the second element in predicted probability and setting threshold to 0.59

# %%
#y_probability
#y_predicted

# %%
import sklearn.metrics as metrics
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import roc_auc_score

# %%
def evaluating_model(y_test, y_probability, y_predicted):
    # AUROC
    fpr, tpr, threshold = metrics.roc_curve(y_test, y_probability[:,1])
    auc_score = metrics.auc(fpr, tpr)
    auc_score  # this is exactly the same as calculating through metrics.roc_auc_score directly

    # AUPRC
    precision, recall, threshold = metrics.precision_recall_curve(y_test, y_probability[:,1])
    auprc_score = metrics.auc(recall, precision)
    auprc_score


    print("Prediction Summary")
    print("--------------------------------------")

    print("Accuracy: {:.2f}".format(accuracy_score(y_test, y_predicted)))
    print("Precision score: {:.2f}".format(precision_score(y_test, y_predicted)))
    print("Recall score: {:.2f}".format(recall_score(y_test, y_predicted)))
    print("F1 score: {:.2f}".format(f1_score(y_test, y_predicted)))
    print("\n")
    print("AUROC score: {:.2f}".format(roc_auc_score(y_test, y_probability[:,1])))
    print("AUPRC score: {:.2f}".format(auprc_score))
    
evaluating_model(y_test, y_probability, y_predicted)
# Out:
# Prediction Summary
# --------------------------------------
# Accuracy: 0.70
# Precision score: 0.71
# Recall score: 0.72
# F1 score: 0.71
#
#
# AUROC score: 0.78
# AUPRC score: 0.76

# %%
import matplotlib.pyplot as plt
fpr, tpr, threshold = metrics.roc_curve(y_test, y_probability[:,1])
auc_score = metrics.auc(fpr, tpr)
precision, recall, threshold = metrics.precision_recall_curve(y_test, y_probability[:,1])
auprc_score = metrics.auc(recall, precision)

plt.title("Receiver operating characteristics")
plt.xlabel("False Positive Rate or True Negative Rate (1-Specificity)")
plt.ylabel("True Positive Rate (Sensitivity)")
plt.xlim([0,1])
plt.ylim([0,1])
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f'%auc_score) # blue auc curve line
plt.legend()
plt.plot([0,1], [0,1], 'r--') # red dashed diagnol line
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title("Receiver operating characteristics")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.xlim([0,1])
plt.ylim([0,1])
plt.plot(precision, recall, 'y', label = 'AUPRC = %0.2f'%auprc_score) # yellow auprc curve line
plt.legend()
plt.plot([0,1], [0,1], 'r--') # red dashed diagnol line
plt.show()

# %% [markdown]
# #### Model has decent precision, recall, f1 score and accuracy. It has good AUROC and AUPRC

# %%
import pickle
filename = "basic_ahe_rf.sav"
pickle.dump
# Out:
# <function _pickle.dump(obj, file, protocol=None, *, fix_imports=True)>

# %% [markdown]
# ## Basic Random Forest for LOS prediction

# %%
train_df = pd.read_csv("../input/train-features-1/boruta_data_los/boruta_train_summ.csv")
val_df = pd.read_csv("../input/train-features-1/boruta_data_los/boruta_val_summ.csv")
test_df = pd.read_csv("../input/train-features-1/boruta_data_los/boruta_test_summ.csv")

# %%
train_df.head()
# Out:
#                id  LOS_disc  X.HR.__abs_energy  \
# 0  p000107_252542         0          -0.863084
# 1  p000177_288571         1          -1.143335
# 2  p000177_288571         1          -1.143335
# 3  p000177_288571         1          -1.143335
# 4  p000177_288571         1          -1.143335
#
#    X.HR.__absolute_sum_of_changes  \
# 0                       -0.666340
# 1                       -0.763745
# 2                       -0.763745
# 3                       -0.763745
# 4                       -0.763745
#
#    X.HR.__agg_autocorrelation__f_agg_.mean.__maxlag_40  \
# 0                                           1.507252
# 1                                          -0.582259
# 2                                          -0.582259
# 3                                          -0.582259
# 4                                          -0.582259
#
#    X.HR.__agg_autocorrelation__f_agg_.median.__maxlag_40  \
# 0                                           1.467062
# 1                                          -0.576513
# 2                                          -0.576513
# 3                                          -0.576513
# 4                                          -0.576513
#
#    X.HR.__agg_autocorrelation__f_agg_.var.__maxlag_40  \
# 0                                          -1.026279
# 1                                           2.709384
# 2                                           2.709384
# 3                                           2.709384
# 4                                           2.709384
#
#    X.HR.__agg_linear_trend__f_agg_.max.__chunk_len_10__attr_.intercept.  \
# 0                                          -1.250568
# 1                                          -1.276166
# 2                                          -1.276166
# 3                                          -1.276166
# 4                                          -1.276166
#
#    X.HR.__agg_linear_trend__f_agg_.max.__chunk_len_10__attr_.rvalue.  \
# 0                                           0.962632
# 1                                           0.222403
# 2                                           0.222403
# 3                                           0.222403
# 4                                           0.222403
#
#    X.HR.__agg_linear_trend__f_agg_.max.__chunk_len_10__attr_.slope.  ...  \
# 0                                           0.872868                 ...
# 1                                           0.168484                 ...
# 2                                           0.168484                 ...
# 3                                           0.168484                 ...
# 4                                           0.168484                 ...
#
#    final_abp_sys__standard_deviation  \
# 0                          -0.769837
# 1                           0.835252
# 2                           0.835252
# 3                           0.835252
# 4                           0.835252
#
#    final_abp_sys__sum_of_reoccurring_data_points  \
# 0                                       0.108120
# 1                                       0.925568
# 2                                       0.925568
# 3                                       0.925568
# 4                                       0.925568
#
#    final_abp_sys__sum_of_reoccurring_values  final_abp_sys__sum_values  \
# 0                                 -0.499646                   -0.14257
# 1                                  2.846669                    1.93629
# 2                                  2.846669                    1.93629
# 3                                  2.846669                    1.93629
# 4                                  2.846669                    1.93629
#
#    final_abp_sys__time_reversal_asymmetry_statistic__lag_1  \
# 0                                          -1.259840
# 1                                           3.036344
# 2                                           3.036344
# 3                                           3.036344
# 4                                           3.036344
#
#    final_abp_sys__time_reversal_asymmetry_statistic__lag_2  \
# 0                                          -1.172745
# 1                                           3.071203
# 2                                           3.071203
# 3                                           3.071203
# 4                                           3.071203
#
#    final_abp_sys__time_reversal_asymmetry_statistic__lag_3  \
# 0                                          -1.115637
# 1                                           3.071963
# 2                                           3.071963
# 3                                           3.071963
# 4                                           3.071963
#
#    final_abp_sys__variance  GENDER       age
# 0                -0.610068       1  0.216704
# 1                 0.514357       1  0.728071
# 2                 0.514357       1  0.728071
# 3                 0.514357       1  0.728071
# 4                 0.514357       1  0.728071
#
# [5 rows x 2748 columns]

# %%
# concatenating train and val
final_train_df = pd.concat((train_df, val_df), axis=0)

# %%
X = final_train_df[final_train_df.columns.difference(['id', 'LOS_disc', 'age', 'GENDER'])]
Y = final_train_df[['LOS_disc']]

X_train = X
y_train = np.array(Y)

# %%
from sklearn.ensemble import RandomForestClassifier
model_los = RandomForestClassifier(n_estimators = 1250)
model_los
# Out:
# RandomForestClassifier(n_estimators=1250)

# %%
model_los.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(n_estimators=1250)

# %%
# Preparing the test set
X = test_df[test_df.columns.difference(['id', 'LOS_disc', 'age', 'GENDER'])]
Y = test_df[['LOS_disc']]

X_test = X
y_test = np.array(Y)

# %%
y_probability = model_los.predict_proba(X_test)
#y_probability
# using threshold 0.3376 to get low false negatives
y_predicted = (y_probability[:,1]>0.3376).astype('int')

# %%
# calling function
evaluating_model(y_test, y_probability, y_predicted)
# Out:
# Prediction Summary
# --------------------------------------
# Accuracy: 0.75
# Precision score: 0.52
# Recall score: 0.65
# F1 score: 0.58
#
#
# AUROC score: 0.77
# AUPRC score: 0.54

# %%
# AUROC
fpr, tpr, threshold = metrics.roc_curve(y_test, y_probability[:,1])
auc_score = metrics.auc(fpr, tpr)
#auc_score  # this is exactly the same as calculating through metrics.roc_auc_score directly

# AUPRC
precision, recall, threshold = metrics.precision_recall_curve(y_test, y_probability[:,1])
auprc_score = metrics.auc(recall, precision)

# %%
import matplotlib.pyplot as plt
plt.title("Receiver operating characteristics")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.xlim([0,1])
plt.ylim([0,1])
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f'%auc_score) # blue auc curve line
plt.legend()
plt.plot([0,1], [0,1], 'r--') # red dashed diagnol line
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title("Receiver operating characteristics")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.xlim([0,1])
plt.ylim([0,1])
plt.plot(precision, recall, 'y', label = 'AUPRC = %0.2f'%auprc_score) # yellow auprc curve line
plt.legend()
plt.plot([0,1], [0,1], 'r--') # red dashed diagnol line
plt.show()

# %% [markdown]
# #### Model shows decent accuracy and also AUC score, however, precision, recall, f1_score and AUPRC are not so good

# %%
filename = "basic_los_rf.sav"
pickle.dump(model_los, open(filename, 'wb'))

# %% [markdown]
# ## Basic Random Forest for Shock prediction

# %%
train_df = pd.read_csv("../input/train-features-2/Boruta_data_shock/boruta_train_summ.csv")
val_df = pd.read_csv("../input/train-features-2/Boruta_data_shock/boruta_val_summ.csv")
test_df = pd.read_csv("../input/train-features-2/Boruta_data_shock/boruta_test_summ.csv")

# %%
train_df.head()
# Out:
#                           id  label  X.HR.__abs_energy  \
# 0   p000107_252542_1_37_1081      1      -573284.93550
# 1  p000208_279205_1_319_9541      0       -83824.23258
# 2   p000214_255525_1_39_1141      1       486377.74450
# 3   p000222_260665_1_91_2701      1      -459539.93550
# 4   p000262_243312_1_40_1171      1       395275.81450
#
#    X.HR.__agg_linear_trend__f_agg_.max.__chunk_len_10__attr_.intercept.  \
# 0                                         -21.715603
# 1                                          -5.372679
# 2                                          10.559611
# 3                                         -12.779705
# 4                                           7.160466
#
#    X.HR.__agg_linear_trend__f_agg_.max.__chunk_len_10__attr_.rvalue.  \
# 0                                           0.827494
# 1                                           0.448493
# 2                                           0.293794
# 3                                          -0.214743
# 4                                           0.788988
#
#    X.HR.__agg_linear_trend__f_agg_.max.__chunk_len_10__attr_.slope.  \
# 0                                           0.449115
# 1                                           0.629486
# 2                                           0.108021
# 3                                          -0.068834
# 4                                           0.309798
#
#    X.HR.__agg_linear_trend__f_agg_.max.__chunk_len_50__attr_.intercept.  \
# 0                                         -23.961665
# 1                                           4.814526
# 2                                           8.109764
# 3                                         -17.128332
# 4                                           4.252621
#
#    X.HR.__agg_linear_trend__f_agg_.max.__chunk_len_50__attr_.rvalue.  \
# 0                                           1.048891
# 1                                           0.572221
# 2                                           0.331317
# 3                                           0.099391
# 4                                           1.129976
#
#    X.HR.__agg_linear_trend__f_agg_.max.__chunk_len_50__attr_.slope.  \
# 0                                           2.805960
# 1                                           1.468817
# 2                                           0.997388
# 3                                           0.505960
# 4                                           2.220245
#
#    X.HR.__agg_linear_trend__f_agg_.max.__chunk_len_5__attr_.intercept.  ...  \
# 0                                         -20.795600                    ...
# 1                                          -6.903406                    ...
# 2                                          11.534444                    ...
# 3                                         -11.571724                    ...
# 4                                           7.792209                    ...
#
#    final_abp_sys__quantile__q_0.2  final_abp_sys__quantile__q_0.3  \
# 0                        2.540665                       -0.197714
# 1                       25.395670                       25.473846
# 2                      -24.645330                      -23.483709
# 3                       -9.829573                      -12.005668
# 4                       18.449769                       16.108508
#
#    final_abp_sys__quantile__q_0.4  final_abp_sys__quantile__q_0.6  \
# 0                       -1.651373                       -2.491844
# 1                       27.774066                       34.586176
# 2                      -22.499651                      -20.013824
# 3                      -14.021610                      -13.737515
# 4                       15.779417                       14.685401
#
#    final_abp_sys__quantile__q_0.7  final_abp_sys__quantile__q_0.8  \
# 0                       -3.050218                       -5.415606
# 1                       38.984580                       44.813281
# 2                      -17.109048                      -13.886719
# 3                      -15.982739                      -17.223560
# 4                       13.818288                       11.452900
#
#    final_abp_sys__quantile__q_0.9  final_abp_sys__sum_values  GENDER  \
# 0                       -6.095397                -373.584377       1
# 1                       50.222072                8708.573101       1
# 2                      -12.727928               -5204.024801       1
# 3                      -20.714769               -3620.209447       0
# 4                        8.523974                3707.274392       1
#
#          age
# 0   3.283013
# 1 -16.338905
# 2  -2.892329
# 3   2.532328
# 4  -2.662192
#
# [5 rows x 558 columns]

# %%
# Shape
print("Shape of training set: ", train_df.shape)
print("Shape of validation set: ", val_df.shape)
print("Shape of test set: ", test_df.shape)
# Out:
# Shape of training set:  (1516, 558)
# Shape of validation set:  (415, 558)
# Shape of test set:  (415, 558)

# %% [markdown]
# Number of patients in training set are 1516 and test and val set are 415 each. Number of features in each set are 558

# %%
# Preparing training set
train_val_df = pd.concat((train_df, val_df), axis=0)
X = train_val_df[train_val_df.columns.difference(['id', 'label', 'age', 'GENDER'])]
Y = train_val_df[['label']]

X_train = X
y_train = np.array(Y)

# %%
# Preparing test set
X = test_df[test_df.columns.difference(['id', 'label', 'age', 'GENDER'])]
Y = test_df[['label']]

X_test = X
y_test = np.array(Y)

# %%
# model
from sklearn.ensemble import RandomForestClassifier
model_shock = RandomForestClassifier(n_estimators=1250)

# %%
model_shock.fit(X_train, y_train)
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   """Entry point for launching an IPython kernel.
# RandomForestClassifier(n_estimators=1250)

# %%
# predicting
y_probability = model_shock.predict_proba(X_test)
y_predicted = (y_probability[:,1]>0.61).astype('int')

# %%
y_predicted[:10]
# Out:
# array([0, 1, 1, 1, 1, 0, 0, 1, 1, 0])

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_predicted)
cm
# Out:
# array([[128,  36],
#        [ 69, 182]])

# %%
evaluating_model(y_test, y_probability, y_predicted)
# Out:
# Prediction Summary
# --------------------------------------
# Accuracy: 0.75
# Precision score: 0.83
# Recall score: 0.73
# F1 score: 0.78
#
#
# AUROC score: 0.84
# AUPRC score: 0.90

# %% [markdown]
# ### Good scores!

# %%
fpr, tpr, threshold = metrics.roc_curve(y_test, y_probability[:,1])
auc_score = metrics.auc(fpr, tpr)

precision, recall, threshold = metrics.precision_recall_curve(y_test, y_probability[:,1])
auprc_score = metrics.auc(recall, precision)

# %%
import matplotlib.pyplot as plt
plt.title("Receiver operating characteristics")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.xlim([0,1])
plt.ylim([0,1])
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f'%auc_score) # blue auroc curve line
plt.legend()
plt.plot([0,1], [0,1], 'r--') # red dashed diagnol line
plt.show()

# %%
import matplotlib.pyplot as plt
plt.title("Receiver operating characteristics")
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.xlim([0,1])
plt.ylim([0,1])
plt.plot(precision, recall, 'y', label = 'AUPRC = %0.2f'%auprc_score) # yellow auprc curve line
plt.legend()
plt.plot([0,1], [0,1], 'r--') # red dashed diagnol line
plt.show()

# %%
filename = "basic_shock_rf.sav"
pickle.dump(model_shock, open(filename, 'wb'))

# %% [markdown]
# ## Predicting on processed features from the dataset uploaded by user in real time

# %%
processed_uploaded_df = pd.read_csv("../input/uploaded-data/Processed_Dataset.csv")

# %%
boruta_ahe_features = pd.read_csv("../input/train-features/boruta_data/boruta_train_summ.csv")

# %%
boruta_features_list = boruta_ahe_features[boruta_ahe_features.columns.difference(['id', 'label', 'age', 'GENDER'])].columns

# %%
boruta_features_list
# Out:
# Index(['X.HR.__approximate_entropy__m_2__r_0.5',
#        'X.HR.__approximate_entropy__m_2__r_0.9',
#        'X.HR.__change_quantiles__f_agg_.var.__isabs_True__qh_0.8__ql_0.6',
#        'X.HR.__cwt_coefficients__widths_.2..5..10..20.__coeff_0__w_2',
#        'X.HR.__energy_ratio_by_chunks__num_segments_10__segment_focus_3',
#        'X.HR.__energy_ratio_by_chunks__num_segments_10__segment_focus_4',
#        'X.HR.__energy_ratio_by_chunks__num_segments_10__segment_focus_7',
#        'X.HR.__fft_coefficient__coeff_10__attr_.abs.',
#        'X.HR.__fft_coefficient__coeff_12__attr_.abs.',
#        'X.HR.__fft_coefficient__coeff_13__attr_.abs.',
#        ...
#        'final_abp_sys__spkt_welch_density__coeff_5',
#        'final_abp_sys__spkt_welch_density__coeff_8',
#        'final_abp_sys__standard_deviation',
#        'final_abp_sys__sum_of_reoccurring_data_points',
#        'final_abp_sys__sum_of_reoccurring_values', 'final_abp_sys__sum_values',
#        'final_abp_sys__time_reversal_asymmetry_statistic__lag_1',
#        'final_abp_sys__time_reversal_asymmetry_statistic__lag_2',
#        'final_abp_sys__time_reversal_asymmetry_statistic__lag_3',
#        'final_abp_sys__variance'],
#       dtype='object', length=442)

# %% [markdown]
# These boruta features are the ones that we want to extract from the uploaded dataset which has been processed so that our pre-trained model can make the prediction

# %%
selected_df = processed_uploaded_df[list(set(processed_uploaded_df.columns) & set(boruta_features_list))]

# removing duplicates
#print("Duplicate columns in the processed uploaded data: ", selected_df.columns.duplicated)
selected_df = selected_df.loc[:, ~selected_df.columns.duplicated()]

# ordering according to the boruta features
selected_df = selected_df[boruta_features_list]

# %%
selected_df.shape
# Out:
# (3, 442)

# %%
selected_df.head()
# Out:
#    X.HR.__approximate_entropy__m_2__r_0.5  \
# 0                                0.152161
# 1                                0.439576
# 2                                0.085902
#
#    X.HR.__approximate_entropy__m_2__r_0.9  \
# 0                                0.120190
# 1                                0.237695
# 2                                0.040298
#
#    X.HR.__change_quantiles__f_agg_.var.__isabs_True__qh_0.8__ql_0.6  \
# 0                                           0.000000
# 1                                           0.041814
# 2                                           1.082152
#
#    X.HR.__cwt_coefficients__widths_.2..5..10..20.__coeff_0__w_2  \
# 0                                           0.001584
# 1                                           1.041557
# 2                                          -0.077716
#
#    X.HR.__energy_ratio_by_chunks__num_segments_10__segment_focus_3  \
# 0                                           0.000661
# 1                                           0.009248
# 2                                          -0.013864
#
#    X.HR.__energy_ratio_by_chunks__num_segments_10__segment_focus_4  \
# 0                                          -0.000520
# 1                                           0.005570
# 2                                          -0.008681
#
#    X.HR.__energy_ratio_by_chunks__num_segments_10__segment_focus_7  \
# 0                                          -0.000835
# 1                                          -0.009793
# 2                                           0.021815
#
#    X.HR.__fft_coefficient__coeff_10__attr_.abs.  \
# 0                                     12.051996
# 1                                     47.703426
# 2                                    152.903044
#
#    X.HR.__fft_coefficient__coeff_12__attr_.abs.  \
# 0                                     12.361479
# 1                                     34.214349
# 2                                     87.418429
#
#    X.HR.__fft_coefficient__coeff_13__attr_.abs.  ...  \
# 0                                     10.323557  ...
# 1                                     43.984010  ...
# 2                                     49.099337  ...
#
#    final_abp_sys__spkt_welch_density__coeff_5  \
# 0                                  412.169757
# 1                                  176.922081
# 2                                  731.611749
#
#    final_abp_sys__spkt_welch_density__coeff_8  \
# 0                                    7.293468
# 1                                    1.906198
# 2                                 1294.858212
#
#    final_abp_sys__standard_deviation  \
# 0                           9.308917
# 1                           5.029854
# 2                           6.704024
#
#    final_abp_sys__sum_of_reoccurring_data_points  \
# 0                                        20631.5
# 1                                        18517.4
# 2                                        18913.1
#
#    final_abp_sys__sum_of_reoccurring_values  final_abp_sys__sum_values  \
# 0                                    8363.3                3260.558346
# 1                                    6318.2               -6627.606767
# 2                                    7589.5               -3512.369333
#
#    final_abp_sys__time_reversal_asymmetry_statistic__lag_1  \
# 0                                       -7843.770264
# 1                                       -1773.385427
# 2                                        2801.991657
#
#    final_abp_sys__time_reversal_asymmetry_statistic__lag_2  \
# 0                                      -17177.159628
# 1                                       -4118.164211
# 2                                        6688.589984
#
#    final_abp_sys__time_reversal_asymmetry_statistic__lag_3  \
# 0                                      -23855.573627
# 1                                       -5474.760531
# 2                                        9305.594593
#
#    final_abp_sys__variance
# 0                86.655931
# 1                25.299426
# 2                44.943941
#
# [3 rows x 442 columns]

# %%
#model_ahe = pickle.load(open('./basic_ahe_rf.sav', 'rb'))

# %%
y_probability = model_ahe.predict_proba(selected_df)
y_predicted = (y_probability[:,1]>=0.5).astype('int')
y_predicted
# Out:
# array([0, 1, 1])

# %% [markdown]
# ### Thus in the uploaded dataset, 1st patient is predicted to be normal however the other 2 are predicted to develop Acute Hypertension episodes abnormalities
